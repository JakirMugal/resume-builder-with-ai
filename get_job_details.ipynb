# %%
import os
from scrapy import Selector
import json
import re
def get_details(text):
    pattern = r"^(.*?)\s+hiring\s+(.*?)\s+in\s+(.*?)\s+\|"
    match = re.search(pattern, text)
    assert match, "Not matched"
    company = match.group(1)
    position = match.group(2)
    location = match.group(3)
    return {
        'company':company,
        'position':position,
        'location':location
    }
def get_details_from_html(base_path):
    job_description_path = rf"{base_path}\job_description.json"
    html_path = rf"{base_path}\job_data"
    link_path_data = rf"{base_path}\link_path_data.json"
    with open(link_path_data,'r') as file:
        json_data = json.loads(file.read())
    meta={}

    for job_name,data in json_data.items():
        print(f'Processing {job_name}')
        if 'jobs/view' not in data['link']:
            continue
        file_path = os.path.join(html_path,data['path'])
        with open(file_path, "r", encoding="utf-8") as file:
            html_content = file.read()
        selector = Selector(text = html_content)
        job_description = '\n'.join(selector.xpath('//div[contains(@class,"description")]//text()').getall())
        page_title = selector.xpath('//title/text()').get()
        assert page_title and job_description , "Data not found"
        meta[job_name] = {
            'path':data['path'],
            'link':data['link'],
            'description':job_description,
            **get_details(page_title)
        }

    with open(job_description_path,'w') as file:
        file.write(json.dumps(meta))
base_path = r"E:\study\GitHub\RESUME-BUILDER-WITH-AI"
get_details_from_html(base_path=base_path)
# Out:
# Processing data-scientist-across-pan-india-at-capgemini-engineering-4228162369.html
# Processing data-scientist-at-valiance-solutions-4075570637.html
# Processing ai-ml-dl-specialist-at-adroit-innovative-solutions-inc-4278565118.html
# Processing data-scientist-at-dexian-india-4264355859.html
# Processing data-scientist-at-recro-4271310370.html
# Processing machine-learning-engineer-at-interview-kickstart-4267255580.html
# Processing research-scientist-%E2%80%93-ai-ml-at-ascendeum-4265400511.html
# Processing data-scientist-people-analytics-at-motive-4257177833.html
# Processing ai-engineer-at-idea-elan-4259182911.html
# Processing senior-data-scientist-at-recro-4271586232.html
# Processing learning-support-specialist-ml-ai-data-science-and-data-engineering-at-emeritus-4259404928.html
# Processing data-scientist-at-hirenza-4279537149.html
# Processing python-developer-sde-2-at-greythr-4264074519.html
# Processing associate-data-scientist-at-ascendeum-4265405159.html
# Processing software-engineer-python-react-at-dexian-india-4273061347.html
# Processing artificial-intelligence-engineer-at-hyqoo-4264456976.html
# Processing ai-developer-at-elegant-enterprise-wide-solutions-inc-4263507628.html
# Processing artificial-intelligence-engineer-at-true-tech-professionals-4277999857.html
# Processing python-developer-remote-at-altraize-4177412286.html
# Processing machine-learning-engineer-at-goml-4275071237.html
# Processing data-analyst-data-scientist-at-weekday-ai-yc-w21-4264836804.html
# Processing python-developer-at-tigi-hr-4277504449.html
# Processing ai-engineer-at-elevation-capital-4277540420.html
# Processing machine-learning-researcher-at-ascendeum-4273411453.html
# Processing python-developer-at-onefin-4257193441.html
# Processing executive-data-scientist-at-ascendeum-4273408579.html
# Processing applied-ai-engineer-india-remote-at-wixjob-4270060681.html
# Processing python-react-developer-at-dexian-india-4272828738.html
# Processing python-developer-at-datastack-technologies-4278062997.html
# Processing python-full-stack-developer-at-altraize-4177184412.html
# Processing front-end-developers-ai-training-remote-at-braintrust-4220208768.html
# Processing software-engineer-machine-learning-at-motive-4264402019.html
# Processing software-engineer-machine-learning-at-motive-4268347933.html
# Processing python-fullstack-developer-at-awign-4271810088.html
# Processing ai-growth-hacker-%E2%80%93-smb-client-acquisition-at-bayinfotech-4277224294.html
# Processing data-scientist-i-at-agco-corporation-4205966935.html
# Processing senior-machine-learning-engineer-at-goml-4275069363.html
# Processing quality-assurance-automation-engineer-at-recro-4263348668.html
# Processing swift-coders-ai-training-remote-at-braintrust-4233232867.html
# Processing ai-engineer-chatbot-at-hire22-ai-4278907819.html
# Processing swift-coders-ai-training-remote-hindi-speakers-encouraged-at-braintrust-4233242911.html
# Processing senior-python-software-engineer-voice-ai-at-checkmate-4267059360.html
# Processing backend-developer-python-intern-at-shiryam-technologies-4257190806.html
# Processing backend-developer-java-python-at-weekday-ai-yc-w21-4276678579.html
# Processing senior-python-developer-at-checkmate-4271406229.html
# Processing search-engineer-at-lucidworks-4275972759.html
# Processing application-engineer-at-vericut-4268459061.html
# Processing front-end-developer-expertise-for-ai-training-at-outlier-4269671349.html
# Processing big-data-developer-at-kresta-softech-private-limited-4272141830.html
# Processing platform-engineer-at-niksun-4255561683.html
# Processing junior-site-reliability-engineer-at-jove-4273783458.html
# Processing founding-engineer-at-weekday-ai-yc-w21-4266732348.html
# Processing data-engineer-web-scraping-at-alternative-path-4268965583.html
# Processing react-native-developer-at-vayuz-technologies-4148628204.html
# Processing software-engineer-at-schedley-com-4271146349.html
# Processing junior-full-stack-engineer-at-dexian-india-4277198569.html
# Processing simulation-triage-engineer-at-imerit-technology-4267949310.html
# Processing software-engineering-specialist-human-data-at-xai-4262541457.html
# Processing software-engineer-backend-development-at-smallcase-4267667521.html
# Processing reactjs-developer-at-kopykitab-digibook-technologies-pvt-ltd-4257190810.html

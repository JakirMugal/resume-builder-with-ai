# %%
import json
from groq import Groq
import os

def create_html_by_ai(base_path):
    job_description_summary = rf"{base_path}\job_description_summary.json"
    personal_details = rf"{base_path}\Jakir Complete Profile.txt"
    job_resume_html = rf"{base_path}\job_resume_html.json"
    with open(job_description_summary,"r") as file:
        jobs = json.loads(file.read())
    with open(personal_details, "r", encoding="utf-8") as file:
        user_resume = file.read().replace('–','-')
    if os.path.exists(job_resume_html):
        with open(job_resume_html, "r", encoding="utf-8") as file:
            already_processed_data = json.load(file)
    else:
        already_processed_data = {}

    api_key ="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"


    client = Groq(api_key=api_key)
    description_prompt = """
    You are an expert resume formatter. Generate a **clean and ATS-friendly HTML resume** using the information I will provide.

    🎯 Follow this structure:

    1. Center the candidate’s **name** at the top in large, colored text.
    2. Below the name, add personal information (smaller font, inline, pointer-separated):
    - ➤ Email (as a clickable hyperlink where link word should be Email)
    - ➤ Phone : number
    - ➤ LinkedIn (as a clickable hyperlink where link word should be LinkedIn)
    - ➤ GitHub (as a clickable hyperlink where link word should be GitHub)
    - ➤ Education : text
    In this Email Phone linkedIn and Git present in a single line and Education in next line and please use  ➤ with every pointer. And do not make too much new lines between these.
    3. Add these **sections with headings in 14px colored font**:
        - **Professional Summary**
        - **Skills**
        - **Work Experience**
        - **Projects**
        - **Certifications**
        - **Achievements**

    📌 Important Instructions:
    - Always include **Projects** and **Work Experience** in the output.
    - **Order the Projects based on relevance to the job description.**
    - Bold all **company names** in Work Experience and Projects.
    - Use a clean, modern font like Segoe UI or Arial.
    - Font sizes: 
        - `h1`: 18px
        - `h2`: 14px
        - list items and content: 11px
    - Color scheme: use `#1e3a8a` for headings and `#2563eb` for links.
    - ✅ Do **not** insert extra line breaks between bullet points — keep spacing minimal to reduce page size.

    🎨 Add this CSS in a `<style>` tag inside the HTML head:

    <style>
        body {
            font-family: 'Segoe UI', sans-serif;
            font-size: 12px;
            margin: 40px;
            color: #222;
            background-color: #f9f9f9;
        }
        h1 {
            font-size: 18px;
            text-align: center;
            color: #1e3a8a;
            margin-bottom: 5px;
        }
        .personal-info {
            text-align: center;
            font-size: 11px;
            color: #444;
            margin-bottom: 20px;
        }
        .personal-info span {
            display: inline-block;
            margin: 0 10px;
        }
        h2 {
            font-size: 14px;
            color: #1e3a8a;
            margin-bottom: 6px;
            border-bottom: 1px solid #ccc;
            padding-bottom: 2px;
        }
        ul {
            padding-left: 16px;
            margin-top: 0;
            margin-bottom: 4px;
        }
        ul li {
            font-size: 11px;
            margin-bottom: 2px;
        }
        b {
            color: #000;
        }
        a {
            color: #2563eb;
            text-decoration: none;
        }
    </style>

    📥 Now, take the user resume data and output a full valid HTML document — compact, styled, and optimized."""
    meta={}
    for job,data in jobs.items():
        print(f"Processing Job: {job}")
        if job in already_processed_data:
            print(f"{job} is already proccesed")
            meta[job]=already_processed_data[job]
            meta[job]['company']=data['company']
            meta[job]['position']=data['position']
            meta[job]['location']=data['location']
            continue
        job_description=data['description_summary'].strip()
        information = f"""
        ----------------------
        ### USER PROFESSIONAL SUMMARY
        {user_resume}

        ----------------------
        ### JOB DESCRIPTION
        {job_description}
        ----------------------

        Please return only the final HTML resume code.
        📥 Now, take the user resume data and output a full valid HTML document.
        """
        user_prompt = f"{description_prompt}\n{information}"
        response = client.chat.completions.create(
                    model="meta-llama/llama-4-scout-17b-16e-instruct",
                    messages=[
                        {"role": "user", "content": user_prompt}
                        ],
                    temperature=0.2,
                    max_tokens=1024*8,
                )
        reply = response.choices[0].message.content
        data['resume_html']=reply
        meta[job] = data
        already_processed_data[job]=data
    with open(job_resume_html,'w') as file:
        file.write(json.dumps(meta))
# Out:
# Processing Job: data-scientist-across-pan-india-at-capgemini-engineering-4228162369.html
# data-scientist-across-pan-india-at-capgemini-engineering-4228162369.html is already proccesed
# Processing Job: data-scientist-at-valiance-solutions-4075570637.html
# data-scientist-at-valiance-solutions-4075570637.html is already proccesed
# Processing Job: data-scientist-at-dexian-india-4264355859.html
# data-scientist-at-dexian-india-4264355859.html is already proccesed
# Processing Job: data-scientist-risk-strategy-sme-at-blucognition-4172315084.html
# data-scientist-risk-strategy-sme-at-blucognition-4172315084.html is already proccesed
# Processing Job: data-scientist-at-recro-4271310370.html
# data-scientist-at-recro-4271310370.html is already proccesed
# Processing Job: machine-learning-engineer-at-interview-kickstart-4267255580.html
# machine-learning-engineer-at-interview-kickstart-4267255580.html is already proccesed
# Processing Job: research-scientist-%E2%80%93-ai-ml-at-ascendeum-4265400511.html
# research-scientist-%E2%80%93-ai-ml-at-ascendeum-4265400511.html is already proccesed
# Processing Job: data-scientist-people-analytics-at-motive-4257177833.html
# data-scientist-people-analytics-at-motive-4257177833.html is already proccesed
# Processing Job: ai-engineer-at-idea-elan-4259182911.html
# ai-engineer-at-idea-elan-4259182911.html is already proccesed
# Processing Job: senior-data-scientist-at-recro-4271586232.html
# senior-data-scientist-at-recro-4271586232.html is already proccesed
# Processing Job: machine-learning-engineer-5-yrs-at-orbion-infotech-4271578510.html
# machine-learning-engineer-5-yrs-at-orbion-infotech-4271578510.html is already proccesed
# Processing Job: learning-support-specialist-ml-ai-data-science-and-data-engineering-at-emeritus-4259404928.html
# learning-support-specialist-ml-ai-data-science-and-data-engineering-at-emeritus-4259404928.html is already proccesed
# Processing Job: data-science-machine-learning-trainer-at-nxtwave-4269444170.html
# data-science-machine-learning-trainer-at-nxtwave-4269444170.html is already proccesed
# Processing Job: python-developer-sde-2-at-greythr-4264074519.html
# python-developer-sde-2-at-greythr-4264074519.html is already proccesed
# Processing Job: associate-data-scientist-at-ascendeum-4265405159.html
# associate-data-scientist-at-ascendeum-4265405159.html is already proccesed
# Processing Job: machine-learning-engineer-at-goml-4271473779.html
# machine-learning-engineer-at-goml-4271473779.html is already proccesed
# Processing Job: ai-developer-at-elegant-enterprise-wide-solutions-inc-4263507628.html
# ai-developer-at-elegant-enterprise-wide-solutions-inc-4263507628.html is already proccesed
# Processing Job: artificial-intelligence-engineer-at-hyqoo-4264456976.html
# artificial-intelligence-engineer-at-hyqoo-4264456976.html is already proccesed
# Processing Job: python-developer-remote-at-altraize-4177412286.html
# python-developer-remote-at-altraize-4177412286.html is already proccesed
# Processing Job: graphdb%2Bpython-developer-at-bounteous-4260864622.html
# graphdb%2Bpython-developer-at-bounteous-4260864622.html is already proccesed
# Processing Job: software-engineer-python-react-at-dexian-india-4273061347.html
# software-engineer-python-react-at-dexian-india-4273061347.html is already proccesed
# Processing Job: data-analyst-data-scientist-at-weekday-ai-yc-w21-4264836804.html
# data-analyst-data-scientist-at-weekday-ai-yc-w21-4264836804.html is already proccesed
# Processing Job: python-developer-at-onefin-4257193441.html
# python-developer-at-onefin-4257193441.html is already proccesed
# Processing Job: executive-data-scientist-at-ascendeum-4273408579.html
# executive-data-scientist-at-ascendeum-4273408579.html is already proccesed
# Processing Job: python-developer-at-people-prime-worldwide-4272821999.html
# python-developer-at-people-prime-worldwide-4272821999.html is already proccesed
# Processing Job: applied-ai-engineer-india-remote-at-wixjob-4270060681.html
# applied-ai-engineer-india-remote-at-wixjob-4270060681.html is already proccesed
# Processing Job: machine-learning-researcher-at-ascendeum-4273411453.html
# machine-learning-researcher-at-ascendeum-4273411453.html is already proccesed
# Processing Job: python-react-developer-at-dexian-india-4272828738.html
# python-react-developer-at-dexian-india-4272828738.html is already proccesed
# Processing Job: python-full-stack-developer-at-altraize-4177184412.html
# python-full-stack-developer-at-altraize-4177184412.html is already proccesed
# Processing Job: front-end-developers-ai-training-remote-at-braintrust-4220208768.html
# front-end-developers-ai-training-remote-at-braintrust-4220208768.html is already proccesed
# Processing Job: software-engineer-machine-learning-at-motive-4264402019.html
# software-engineer-machine-learning-at-motive-4264402019.html is already proccesed
# Processing Job: software-engineer-machine-learning-at-motive-4268347933.html
# software-engineer-machine-learning-at-motive-4268347933.html is already proccesed
# Processing Job: python-fullstack-developer-at-awign-4271810088.html
# python-fullstack-developer-at-awign-4271810088.html is already proccesed
# Processing Job: ai-growth-hacker-%E2%80%93-smb-client-acquisition-at-bayinfotech-4277224294.html
# ai-growth-hacker-%E2%80%93-smb-client-acquisition-at-bayinfotech-4277224294.html is already proccesed
# Processing Job: senior-machine-learning-engineer-at-goml-4273601599.html
# senior-machine-learning-engineer-at-goml-4273601599.html is already proccesed
# Processing Job: data-scientist-i-at-agco-corporation-4205966935.html
# data-scientist-i-at-agco-corporation-4205966935.html is already proccesed
# Processing Job: quality-assurance-automation-engineer-at-recro-4263348668.html
# quality-assurance-automation-engineer-at-recro-4263348668.html is already proccesed
# Processing Job: swift-coders-ai-training-remote-at-braintrust-4233232867.html
# swift-coders-ai-training-remote-at-braintrust-4233232867.html is already proccesed
# Processing Job: backend-developer-java-python-at-weekday-ai-yc-w21-4276678579.html
# backend-developer-java-python-at-weekday-ai-yc-w21-4276678579.html is already proccesed
# Processing Job: swift-coders-ai-training-remote-hindi-speakers-encouraged-at-braintrust-4233242911.html
# swift-coders-ai-training-remote-hindi-speakers-encouraged-at-braintrust-4233242911.html is already proccesed
# Processing Job: senior-python-software-engineer-voice-ai-at-checkmate-4267059360.html
# senior-python-software-engineer-voice-ai-at-checkmate-4267059360.html is already proccesed
# Processing Job: software-engineer-at-itco-solutions-inc-4271759645.html
# software-engineer-at-itco-solutions-inc-4271759645.html is already proccesed
# Processing Job: backend-developer-python-intern-at-shiryam-technologies-4257190806.html
# backend-developer-python-intern-at-shiryam-technologies-4257190806.html is already proccesed
# Processing Job: big-data-developer-at-kresta-softech-private-limited-4272141830.html
# big-data-developer-at-kresta-softech-private-limited-4272141830.html is already proccesed
# Processing Job: junior-site-reliability-engineer-at-jove-4273783458.html
# junior-site-reliability-engineer-at-jove-4273783458.html is already proccesed
# Processing Job: software-engineer-in-test-i-at-quartic-ai-4259552527.html
# software-engineer-in-test-i-at-quartic-ai-4259552527.html is already proccesed
# Processing Job: application-engineer-at-vericut-4268459061.html
# application-engineer-at-vericut-4268459061.html is already proccesed
# Processing Job: junior-developer-at-live-connections-4270262908.html
# junior-developer-at-live-connections-4270262908.html is already proccesed
# Processing Job: platform-engineer-at-niksun-4255561683.html
# platform-engineer-at-niksun-4255561683.html is already proccesed
# Processing Job: founding-engineer-at-weekday-ai-yc-w21-4266732348.html
# founding-engineer-at-weekday-ai-yc-w21-4266732348.html is already proccesed
# Processing Job: data-engineer-web-scraping-at-alternative-path-4268965583.html
# data-engineer-web-scraping-at-alternative-path-4268965583.html is already proccesed
# Processing Job: react-native-developer-at-vayuz-technologies-4148628204.html
# react-native-developer-at-vayuz-technologies-4148628204.html is already proccesed
# Processing Job: simulation-triage-engineer-at-imerit-technology-4267949310.html
# simulation-triage-engineer-at-imerit-technology-4267949310.html is already proccesed
# Processing Job: fullstack-developer-at-weekday-ai-yc-w21-4277467927.html
# fullstack-developer-at-weekday-ai-yc-w21-4277467927.html is already proccesed
# Processing Job: software-engineer-at-schedley-com-4271146349.html
# software-engineer-at-schedley-com-4271146349.html is already proccesed
# Processing Job: software-engineering-specialist-human-data-at-xai-4262541457.html
# software-engineering-specialist-human-data-at-xai-4262541457.html is already proccesed
# Processing Job: mel-specialist-remote-8-lpa-at-job-express-4258644795.html
# mel-specialist-remote-8-lpa-at-job-express-4258644795.html is already proccesed
# Processing Job: software-engineer-backend-development-at-smallcase-4267667521.html
# software-engineer-backend-development-at-smallcase-4267667521.html is already proccesed
# Processing Job: sde-3-backend-engineer-at-weekday-ai-yc-w21-4270632427.html
# sde-3-backend-engineer-at-weekday-ai-yc-w21-4270632427.html is already proccesed
# Processing Job: software-developer-at-bu-consultants-4273066388.html
# software-developer-at-bu-consultants-4273066388.html is already proccesed

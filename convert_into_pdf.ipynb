# %%
from xhtml2pdf import pisa
from io import BytesIO
import json
import pandas as pd
import os
resume_html_path = r"E:\study\GitHub\RESUME-BUILDER-WITH-AI\job_resume_html.json"
resume_folder_path = html_path = r"E:\study\GitHub\RESUME-BUILDER-WITH-AI\Resumes"
meta_path = r"E:\study\GitHub\RESUME-BUILDER-WITH-AI\job_resume_combined.csv"
os.makedirs(resume_folder_path, exist_ok=True)
with open(resume_html_path,"r") as file:
    jobs = json.loads(file.read())
meta=[]
for job,data in jobs.items():
    print(f"Processing Job: {job}")
    filename = job.replace(".html",".pdf")
    
    full_path = os.path.join(resume_folder_path, filename)
    meta.append(
        {
            'Company':data['company'],
            'Location':data['location'],
            'Position':data['position'],
            'Link':data['link'],
            "Resume Path":full_path
        }
    )
    if os.path.exists(full_path):
        print(f"{filename} already present.....")
        continue
    reply = data['resume_html']
    pdf_buffer = BytesIO()
    pisa.CreatePDF(reply, dest=pdf_buffer)
    pdf_buffer.seek(0)

    # Save to file
    with open(full_path, "wb") as f:
        f.write(pdf_buffer.getbuffer())

    print(f"PDF saved as {filename}")


df=pd.DataFrame(meta)
df.to_csv(meta_path,index=False)
# Out:
# Processing Job: data-scientist-across-pan-india-at-capgemini-engineering-4228162369.html
# data-scientist-across-pan-india-at-capgemini-engineering-4228162369.pdf already present.....
# Processing Job: data-scientist-at-valiance-solutions-4075570637.html
# data-scientist-at-valiance-solutions-4075570637.pdf already present.....
# Processing Job: data-scientist-at-dexian-india-4264355859.html
# data-scientist-at-dexian-india-4264355859.pdf already present.....
# Processing Job: data-scientist-risk-strategy-sme-at-blucognition-4172315084.html
# data-scientist-risk-strategy-sme-at-blucognition-4172315084.pdf already present.....
# Processing Job: data-scientist-at-recro-4271310370.html
# data-scientist-at-recro-4271310370.pdf already present.....
# Processing Job: machine-learning-engineer-at-interview-kickstart-4267255580.html
# machine-learning-engineer-at-interview-kickstart-4267255580.pdf already present.....
# Processing Job: research-scientist-%E2%80%93-ai-ml-at-ascendeum-4265400511.html
# research-scientist-%E2%80%93-ai-ml-at-ascendeum-4265400511.pdf already present.....
# Processing Job: data-scientist-people-analytics-at-motive-4257177833.html
# data-scientist-people-analytics-at-motive-4257177833.pdf already present.....
# Processing Job: ai-engineer-at-idea-elan-4259182911.html
# ai-engineer-at-idea-elan-4259182911.pdf already present.....
# Processing Job: senior-data-scientist-at-recro-4271586232.html
# senior-data-scientist-at-recro-4271586232.pdf already present.....
# Processing Job: machine-learning-engineer-5-yrs-at-orbion-infotech-4271578510.html
# machine-learning-engineer-5-yrs-at-orbion-infotech-4271578510.pdf already present.....
# Processing Job: learning-support-specialist-ml-ai-data-science-and-data-engineering-at-emeritus-4259404928.html
# learning-support-specialist-ml-ai-data-science-and-data-engineering-at-emeritus-4259404928.pdf already present.....
# Processing Job: data-science-machine-learning-trainer-at-nxtwave-4269444170.html
# data-science-machine-learning-trainer-at-nxtwave-4269444170.pdf already present.....
# Processing Job: python-developer-sde-2-at-greythr-4264074519.html
# python-developer-sde-2-at-greythr-4264074519.pdf already present.....
